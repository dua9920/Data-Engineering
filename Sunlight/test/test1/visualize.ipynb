# %%
import pandas as pd
import calendar as cal
import datetime
import re
from glob import glob
from PIL import Image

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from matplotlib import font_manager, rc

font_path = "C:/Windows/Fonts/malgun.ttf"
font_name= font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
wheather_energy = pd.read_csv('./날씨별발전량_울산2.csv')
wheather_energy.head()
# Out:
#                  시간  예측기온  예측습도  예측풍속   예측풍향  날씨코드  관측기온  관측풍속   관측풍향  관측습도  \
# 0  2018-03-01 15:00   8.0  20.0  14.0  298.0   2.0   9.9   7.2  290.0  19.0
# 1  2018-03-01 18:00   4.0  20.0   4.3  298.0   2.0   6.6   2.3  360.0  19.0
# 2  2018-03-01 18:00   4.0  20.0   4.3  298.0   2.0   6.6   2.3  360.0  19.0
# 3  2018-03-02 09:00   0.0  35.0   1.6  320.0   1.0  -0.1   2.7  340.0  46.0
# 4  2018-03-02 09:00   0.0  35.0   1.6  320.0   1.0  -0.1   2.7  340.0  46.0
#
#    전운량  울산발전량
# 0  5.0  318.0
# 1  2.0   30.0
# 2  2.0   30.0
# 3  1.0  102.0
# 4  1.0  102.0

# %%
test = wheather_energy.loc[:2]
test
# Out:
#                  시간  예측기온  예측습도  예측풍속   예측풍향  날씨코드  관측기온  관측풍속   관측풍향  관측습도  \
# 0  2018-03-01 15:00   8.0  20.0  14.0  298.0   2.0   9.9   7.2  290.0  19.0
# 1  2018-03-01 18:00   4.0  20.0   4.3  298.0   2.0   6.6   2.3  360.0  19.0
# 2  2018-03-01 18:00   4.0  20.0   4.3  298.0   2.0   6.6   2.3  360.0  19.0
#
#    전운량  울산발전량
# 0  5.0  318.0
# 1  2.0   30.0
# 2  2.0   30.0

# %%
sns.pairplot(test, vars=['시간', '예측기온'], height=4)
plt.show()
